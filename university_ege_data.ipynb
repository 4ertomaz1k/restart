# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np





data = {
    '№': range(1, 21),
    'id': [
        4032772, 4527913, 4403127, 4223573, 3947019, 4608508, 4242850,
        4395206, 4338865, 3873844, 3952704, 3784978, 4604163, 4449304,
        3943602, 4469305, 4334991, 3820487, 4013792, 4392377
    ],
    'Р': [94, 81, 89, 91, 86, 86, 89, 89, 86, 86, 75, 67, 73, 89, 86, 86, 86, 66, 81, 70],
    'М': [97, 88, 78, 76, 78, 72, 78, 76, 78, 76, 78, 84, 82, 74, 70, 80, 80, 82, 78, 80],
    'Ф': [82, np.nan, np.nan, np.nan, 94, 67, np.nan, 51, np.nan, np.nan, 64, 79, np.nan, np.nan, np.nan, np.nan, 74, np.nan, np.nan, np.nan],
    'И': [np.nan, 95, 83, 88, np.nan, 88, 85, 85, 78, 85, 83, 90, 88, 70, 80, 75, np.nan, 85, 75, 80],
    'О': [np.nan] * 20,
    'ИЯ': [np.nan] * 20,
    'Х': [np.nan] * 20,
    'ПМ': [np.nan] * 20,
    'ПИ': [np.nan] * 20,
    'Мех': [np.nan] * 20,
    'ОЭиЭ': [np.nan] * 20,
    'ОЭ': [np.nan] * 20,
    'ИД': [5, 5, 10, 5, np.nan, 7, np.nan, np.nan, 5, np.nan, 8, 2, np.nan, 10, 7, np.nan, np.nan, 5, 2, 5],
    'Σ': [278, 269, 260, 260, 258, 253, 252, 250, 247, 247, 244, 243, 243, 243, 243, 241, 240, 238, 236, 235]
}

# Создание DataFrame
df = pd.DataFrame(data)

# Установка '№ п/п' в качестве индекса (по желанию, для соответствия с таблицей)
df.set_index('№', inplace=True)

# Проверка и вывод результата
print("Датасет успешно создан. Ниже представлена таблица для проверки:")
print(df.to_string())
# Out:
# Датасет успешно создан. Ниже представлена таблица для проверки:
#          id   Р   М     Ф     И   О  ИЯ   Х  ПМ  ПИ  Мех  ОЭиЭ  ОЭ    ИД    Σ
# №
# 1   4032772  94  97  82.0   NaN NaN NaN NaN NaN NaN  NaN   NaN NaN   5.0  278
# 2   4527913  81  88   NaN  95.0 NaN NaN NaN NaN NaN  NaN   NaN NaN   5.0  269
# 3   4403127  89  78   NaN  83.0 NaN NaN NaN NaN NaN  NaN   NaN NaN  10.0  260
# 4   4223573  91  76   NaN  88.0 NaN NaN NaN NaN NaN  NaN   NaN NaN   5.0  260
# 5   3947019  86  78  94.0   NaN NaN NaN NaN NaN NaN  NaN   NaN NaN   NaN  258
# 6   4608508  86  72  67.0  88.0 NaN NaN NaN NaN NaN  NaN   NaN NaN   7.0  253
# 7   4242850  89  78   NaN  85.0 NaN NaN NaN NaN NaN  NaN   NaN NaN   NaN  252
# 8   4395206  89  76  51.0  85.0 NaN NaN NaN NaN NaN  NaN   NaN NaN   NaN  250
# 9   4338865  86  78   NaN  78.0 NaN NaN NaN NaN NaN  NaN   NaN NaN   5.0  247
# 10  3873844  86  76   NaN  85.0 NaN NaN NaN NaN NaN  NaN   NaN NaN   NaN  247
# 11  3952704  75  78  64.0  83.0 NaN NaN NaN NaN NaN  NaN   NaN NaN   8.0  244
# 12  3784978  67  84  79.0  90.0 NaN NaN NaN NaN NaN  NaN   NaN NaN   2.0  243
# 13  4604163  73  82   NaN  88.0 NaN NaN NaN NaN NaN  NaN   NaN NaN   NaN  243
# 14  4449304  89  74   NaN  70.0 NaN NaN NaN NaN NaN  NaN   NaN NaN  10.0  243
# 15  3943602  86  70   NaN  80.0 NaN NaN NaN NaN NaN  NaN   NaN NaN   7.0  243
# 16  4469305  86  80   NaN  75.0 NaN NaN NaN NaN NaN  NaN   NaN NaN   NaN  241
# 17  4334991  86  80  74.0   NaN NaN NaN NaN NaN NaN  NaN   NaN NaN   NaN  240
# 18  3820487  66  82   NaN  85.0 NaN NaN NaN NaN NaN  NaN   NaN NaN   5.0  238
# 19  4013792  81  78   NaN  75.0 NaN NaN NaN NaN NaN  NaN   NaN NaN   2.0  236
# 20  4392377  70  80   NaN  80.0 NaN NaN NaN NaN NaN  NaN   NaN NaN   5.0  235

# %%
print(f'Русский: {df['Р'].quantile(0)} - я хуже всех написал русский')
print(f'Математика: {df['М'].quantile(0.8)} - я написал матешу лучше чем 80%')
print(f'Физика: {df['Ф'].quantile(0)} - ну физику я то не писал')
print(f'Информатика: {df['И'].quantile(0.5)} - прямо в медиану попал')
# Out:
# Русский: 66.0 - я хуже всех написал русский
# Математика: 82.0 - я написал матешу лучше чем 80%
# Физика: 51.0 - ну физику я то не писал
# Информатика: 85.0 - прямо в медиану попал

# %%
plt.figure(figsize=(20,10))

plt.subplot(1,4,1)
sns.boxplot(y=df['Р'])
plt.title('Русский')

plt.subplot(1,4,2)
sns.boxplot(y=df['М'])
plt.title('Математика')

plt.subplot(1,4,3)
sns.boxplot(y=df['Ф'])
plt.title('Физика')

plt.subplot(1,4,4)
sns.boxplot(y=df['И'])
plt.title('Информатика')

plt.show()
